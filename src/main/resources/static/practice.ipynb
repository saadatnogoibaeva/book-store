# %% [markdown]
# # Churn Prediction Practice

# %% [markdown]
# Q1) Импортируйте все необходимые библиотеки как numpy, pandas, sklearn и т. д.

# %% [markdown]
# Q2) Импортируйте данные

# %% [markdown]
# Q3) Показать данные

# %% [markdown]
# Q4) Выполнить предварительную обработку данных

# %% [markdown]
# Q5) Разделите ваши данные на обучающие и тестовые наборы

# %% [markdown]
# Q6) Выберите 4 алгоритма

# %% [markdown]
# Q7) Примените модель к тестовому набору

# %% [markdown]
# Q8) Точность должна быть не менее 85% в одном из алгоритмов. Если он меньше 85%, попробуйте его улучшить...
